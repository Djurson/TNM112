# %% [markdown]
# # TNM112 -- Lab 2

# %% [markdown]
# ### Data generation
# Look through the "data_generator.py" code to understand how the dataset is generated and plotted.
#
# A dataset can be generated with a randomly selected subset of training images, and with a specified fraction used to formulate a validation set. Here, we use the MNIST dataset of handwritten digits.

# %%
import data_generator

data = data_generator.DataGenerator()
data.generate(dataset='mnist', N_valid=0.1)
data.plot()
# Out:
# Data specification:
# 	Dataset type:           mnist
# 	Number of classes:      10
# 	Number of channels:     1
# 	Training data shape:    (54000, 28, 28, 1)
# 	Validation data shape:  (6000, 28, 28, 1)
# 	Test data shape:        (10000, 28, 28, 1)

# %% [markdown]
# ### Keras CNN
# A small CNN in Keras, trained with cross-entropy loss
#
# We use the functions in 'util.py' to evaluate the model and plot the training progress.

# %%
from tensorflow import keras
from tensorflow.keras import layers
import util

keras.backend.clear_session()

model = keras.Sequential()
model.add(layers.InputLayer(input_shape=data.x_train.shape[1:]))
model.add(layers.Conv2D(4, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Conv2D(8, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(data.K, activation='softmax'))
model.summary()

opt = keras.optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
log = model.fit(data.x_train, data.y_train_oh, batch_size=128, epochs=10, 
                validation_data=(data.x_valid, data.y_valid_oh), verbose=True)

util.evaluate(model, data, final=True)
util.plot_training(log)
# Out:
# /Users/emildjurson/Documents/GitHub/TNM112/venv/lib/python3.13/site-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 28, 28, 4)      │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 4)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 14, 14, 8)      │           296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 7, 7, 8)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 392)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │         3,930 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,266 (16.66 KB)
#  Trainable params: 4,266 (16.66 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8184 - loss: 0.6297 - val_accuracy: 0.9245 - val_loss: 0.2447
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9436 - loss: 0.1894 - val_accuracy: 0.9497 - val_loss: 0.1629
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9581 - loss: 0.1375 - val_accuracy: 0.9600 - val_loss: 0.1339
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9654 - loss: 0.1140 - val_accuracy: 0.9655 - val_loss: 0.1139
# Epoch 5/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9692 - loss: 0.1012 - val_accuracy: 0.9647 - val_loss: 0.1111
# Epoch 6/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9720 - loss: 0.0912 - val_accuracy: 0.9685 - val_loss: 0.0982
# Epoch 7/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9739 - loss: 0.0843 - val_accuracy: 0.9700 - val_loss: 0.0965
# Epoch 8/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9757 - loss: 0.0792 - val_accuracy: 0.9725 - val_loss: 0.0866
# Epoch 9/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9771 - loss: 0.0743 - val_accuracy: 0.9752 - val_loss: 0.0814
# Epoch 10/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9788 - loss: 0.0703 - val_accuracy: 0.9752 - val_loss: 0.0814
# Model performance:
# 	Train loss:          0.0660
# 	Train accuracy:      97.97
# 	Test loss:           0.0680
# 	Test accuracy:       97.83

# %% [markdown]
# ### Our CNN
#
# #### Task 1
# Implement the following functions in cnn.py: 'activation', 'conv2d_layer', 'pool2d_layer', 'flatten_layer', 'dense_layer', and 'evaluate'. Additionally, compute the number of weights in the model, in the function 'setup_model'.
#
# For the 'activation' and 'dense_layer' functions you can use code that you wrote in Lab 1. For the 'evaluate' function you can use the code from Lab 1 for the accuracy. However, now we have trained with the cross-entropy loss, so you should evaluate this loss function through our CNN.
#
# When you have finished the implementation, you should be able to run this code and get the same result as with the Keras model above. However, our code is not optimized, nor parallelized, so it will be rather slow to process the full dataset. In order to facilitate comparisons when you implement the functions, please have a look in the next cell below.

# %%
import importlib
import cnn
importlib.reload(cnn)

# Get the weight matrices and biases of the trained Keras model
W, b, lname = util.get_weights(model)

# This is our implementation of a CNN, which we set to use the dataset we generated
cnn = cnn.CNN(data, verbose=True)

# Assign the weights and biases to the CNN and specify the activation function
cnn.setup_model(W, b, lname, activation='relu')

# Evaluate the model (accuracy on the training and test data)
cnn.evaluate()
# Out:
# Number of model weights:  12
# Model performance:
# sample 0 of 54000
# sample 1000 of 54000
# sample 2000 of 54000
# sample 3000 of 54000
# sample 4000 of 54000
# sample 5000 of 54000
# sample 6000 of 54000
# sample 7000 of 54000
# sample 8000 of 54000
# sample 9000 of 54000
# sample 10000 of 54000
# sample 11000 of 54000
# sample 12000 of 54000
# sample 13000 of 54000
# sample 14000 of 54000
# sample 15000 of 54000
# sample 16000 of 54000
# sample 17000 of 54000
# sample 18000 of 54000
# sample 19000 of 54000
# sample 20000 of 54000
# sample 21000 of 54000
# sample 22000 of 54000
# sample 23000 of 54000
# sample 24000 of 54000
# sample 25000 of 54000
# sample 26000 of 54000
# sample 27000 of 54000
# sample 28000 of 54000
# sample 29000 of 54000
# sample 30000 of 54000
# sample 31000 of 54000
# sample 32000 of 54000
# sample 33000 of 54000
# sample 34000 of 54000
# sample 35000 of 54000
# sample 36000 of 54000
# sample 37000 of 54000
# sample 38000 of 54000
# sample 39000 of 54000
# sample 40000 of 54000
# sample 41000 of 54000
# sample 42000 of 54000
# sample 43000 of 54000
# sample 44000 of 54000
# sample 45000 of 54000
# sample 46000 of 54000
# sample 47000 of 54000
# sample 48000 of 54000
# sample 49000 of 54000
# sample 50000 of 54000
# sample 51000 of 54000
# sample 52000 of 54000
# sample 53000 of 54000
# 	Train loss:     0.0031
# 	Train accuracy: 97.97
# sample 0 of 10000
# sample 1000 of 10000
# sample 2000 of 10000
# sample 3000 of 10000
# sample 4000 of 10000
# sample 5000 of 10000
# sample 6000 of 10000
# sample 7000 of 10000
# sample 8000 of 10000
# sample 9000 of 10000
# 	Test loss:      0.0031
# 	Test accuracy:  97.83

# %% [markdown]
# ### Evaluation of our CNN layers
#
# #### Task 1
# As part of the implementation of the different layers in 'cnn.py', you can use the below code to compare the output of a randomly initialized Keras model and our CNN, for a single image. This is fast to compute, which will be convenient to check that your layers are correctly implemented.

# %%
import numpy as np
import cnn
importlib.reload(cnn)

# Secify a test layer for comparison: 'conv', 'pool', 'flatten', or 'dense'
test_layer = 'conv'

keras.backend.clear_session()

# Keras model and input layer
model = keras.Sequential()
model.add(layers.InputLayer(input_shape=data.x_train.shape[1:]))

# Test conv layer
#   - We apply normal initialization to the bias also,
#     otherwise it would be difficult to see the impact
#     of how you apply the bias (it is initialized to 0 by default)
if test_layer == 'conv':
    model.add(layers.Conv2D(4, kernel_size=(3, 3), 
                            activation='relu', padding='same',
                            bias_initializer='normal'))
    
    # You could also test to add a second convolutional layer, to check
    # that your network maps correctly from the output channels of the
    # previous layer, to the channels of this layer
    #model.add(layers.Conv2D(4, kernel_size=(3, 3), 
    #                        activation='relu', padding='same',
    #                        bias_initializer='normal'))

# Test pooling layer
elif test_layer == 'pool':
    model.add(layers.MaxPooling2D(pool_size=(2, 2)))

# Test flattening layer
elif test_layer == 'flatten':
    model.add(layers.Flatten())

# Test dense layer
#   - We need to first flatten the image input to apply a dense layer
#   - Make sure that your flatten layer works before testing the dense layer
elif test_layer == 'dense':
    model.add(layers.Flatten())
    model.add(layers.Dense(10, activation='softmax',
                           bias_initializer='normal'))

# Test data point (you could select any other image if you want)
x = data.x_train[0]

# Keras prediction. We need ta add an extra axis, 
# since the model can run over multiple datapoints. We 
# would need this in our model also if we use used the
# 'feedforward' function instead of the 'feedforward_sample'
y1 = model.predict(x[np.newaxis,:,:,:], verbose=False)

# Prediction with our network
W, b, lname = util.get_weights(model)  # Get the Keras model weights
cnn = cnn.CNN(data)
cnn.setup_model(W, b, lname, activation='relu') # Assign weights to our model
y2 = cnn.feedforward_sample(x) # Feedforward of one single sample

print('Evaluation of %s layer:'%test_layer)

# Check that the dimensionality is correct. The Keras
# model will have an extra first dimension due to the
# batch processing
print('\tShape of Keras output:  ', y1.shape)
print('\tShape of our output:    ', y2.shape)

# Print the absolute sum of output from the Keras
# model and our model. These should be the same if the
# implementation is correct
print('\tAbs sum of Keras model: ', np.sum(np.abs(y1)))
print('\tAbs sum of our model:   ', np.sum(np.abs(y2)))

# Print the absolute difference between the Keras
# model and our model. This should be very close
# to 0 if your implementation is correct. It could be
# a very minor difference due to numerical differences 
# (e.g., difference in precision used)
print('\tAbs difference:         ', np.sum(np.abs(y1-y2)))
# Out:
# Number of model weights:  2
# Evaluation of conv layer:
# 	Shape of Keras output:   (1, 32, 32, 4)
# 	Shape of our output:     (32, 32, 4)
# 	Abs sum of Keras model:  202.64615
# 	Abs sum of our model:    202.6461591012776
# 	Abs difference:          2.5004148483276367e-05

# %% [markdown]
# ### MNIST with limited training data
# #### Task 2
# In this experiment, we select a random subset from MNIST, with only 128 images. This is a very minimal dataset, but it is interesting to see how overfitting can be prevented with regularization strategies.
#
# Your task is to expand the given network with different regularization strategies. You are free to choose which combination of strategies you want to use, for example augmentation layers, dropout, weight decay, batch normalization, etc. You can also expand the network with more layers, strided convolutions, or add skip-connections to facilitate optimization. Moreover, you can experiment with the number of training epochs and the batch size.
#
# Also, note that now we have specified the Keras network in a sligthly different way. We explicitly formulate the input and output to the different layers. One motiviation for this is that it is easier if we want to, e.g., add skip-connections (checkout the layers.Add() layer in Keras).
#
# During your development, you test the performance on the validation set (util.evaluate with the flag final=False). When you have found a good setup, run evaluation on the test set (final=True). Do this for at least 5 runs and report the average and the variance across models. Since the subset of 128 images is randomly selected and the optimization is stochastic, you will get slightly different values each time. Thus, averaging is important to get a robust indication of your model's performance. You can do this manually, or you can setup a for-loop to run a sequence of trainings, where you log the evaluation results for each model.
#
# For the final results, you should aim at having an average accuracy of at least 90% (which is quite good considering that we are only training on 128 images).

# %%
# A block of convolutional layers followed by max pooling
def conv_block(x, N, channels, kernel_size, activation, padding='same'):
    for i in range(N):
        x = layers.Conv2D(channels, kernel_size=kernel_size, activation=activation, padding=padding)(x)
    return layers.MaxPooling2D(pool_size=(2, 2))(x)
    
epochs = 200
batch_size = 64

# For setting up averaging over multiple training runs
#K = 5
#acc = np.zeros((K,2))
#for k in range(K):

# MNIST with 128 randomly selected training images
data = data_generator.DataGenerator()
data.generate(dataset='mnist', N_train=128)

keras.backend.clear_session()

x      = layers.Input(shape=data.x_train.shape[1:])
conv1  = conv_block(x, N=2, channels=8, kernel_size=(3,3), activation='relu', padding='same')
conv2  = conv_block(conv1, N=2, channels=16, kernel_size=(3,3), activation='relu', padding='same')
conv3  = conv_block(conv2, N=2, channels=32, kernel_size=(3,3), activation='relu', padding='same')
flat1  = layers.Flatten()(conv3)

dense1 = layers.Dense(512, activation='relu')(flat1)
y = layers.Dense(data.K, activation='softmax')(dense1)

model = keras.models.Model(inputs=x, outputs=y)
model.summary()

opt = keras.optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
log = model.fit(data.x_train, data.y_train_oh, batch_size=batch_size, epochs=epochs, 
                validation_data=(data.x_valid, data.y_valid_oh), validation_freq=10,  # We don't need to evaluate at each epoch
                verbose=True)

util.evaluate(model, data, final=False)
util.plot_training(log)

# When you are finished with hyper-parameter tuning, you should evaluate
# your model on the test set, and average over 5 trainings. If you want
# to do this automatically, you can setup a foor loop and store each evaluation
#acc[k,:] = util.evaluate(model, data, final=True)
# Out:
# Data specification:
# 	Dataset type:           mnist
# 	Number of classes:      10
# 	Number of channels:     1
# 	Training data shape:    (128, 28, 28, 1)
# 	Validation data shape:  (6000, 28, 28, 1)
# 	Test data shape:        (10000, 28, 28, 1)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 28, 28, 8)      │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 28, 28, 8)      │           584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 14, 14, 16)     │         1,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 14, 14, 16)     │         2,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 7, 7, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 7, 7, 32)       │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 7, 7, 32)       │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 3, 3, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 288)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       147,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 171,138 (668.51 KB)
#  Trainable params: 171,138 (668.51 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.1094 - loss: 2.3150
# Epoch 2/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1328 - loss: 2.2840
# Epoch 3/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1719 - loss: 2.2698
# Epoch 4/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2500 - loss: 2.2526
# Epoch 5/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2578 - loss: 2.2227
# Epoch 6/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2734 - loss: 2.1845
# Epoch 7/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2969 - loss: 2.1159
# Epoch 8/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3359 - loss: 2.0296
# Epoch 9/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5156 - loss: 1.8941
# Epoch 10/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.6172 - loss: 1.6927 - val_accuracy: 0.5807 - val_loss: 1.6811
# Epoch 11/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6562 - loss: 1.4773
# Epoch 12/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7188 - loss: 1.2509
# Epoch 13/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7266 - loss: 1.0151
# Epoch 14/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7734 - loss: 0.8515
# Epoch 15/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7734 - loss: 0.6978
# Epoch 16/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8047 - loss: 0.6430
# Epoch 17/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8203 - loss: 0.5429
# Epoch 18/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8047 - loss: 0.5880
# Epoch 19/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8203 - loss: 0.4775
# Epoch 20/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.8438 - loss: 0.5051 - val_accuracy: 0.7580 - val_loss: 0.8408
# Epoch 21/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9062 - loss: 0.3476
# Epoch 22/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8672 - loss: 0.3710
# Epoch 23/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9219 - loss: 0.2770
# Epoch 24/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9297 - loss: 0.2570
# Epoch 25/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9453 - loss: 0.2124
# Epoch 26/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9453 - loss: 0.1699
# Epoch 27/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9688 - loss: 0.1379
# Epoch 28/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9766 - loss: 0.1187
# Epoch 29/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9766 - loss: 0.1004
# Epoch 30/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 1.0000 - loss: 0.0761 - val_accuracy: 0.7947 - val_loss: 0.8400
# Epoch 31/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0642
# Epoch 32/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0547
# Epoch 33/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0416
# Epoch 34/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0381
# Epoch 35/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0294
# Epoch 36/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0257
# Epoch 37/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0209
# Epoch 38/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0171
# Epoch 39/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0139
# Epoch 40/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 0.8000 - val_loss: 1.0322
# Epoch 41/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0102
# Epoch 42/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0084
# Epoch 43/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0075
# Epoch 44/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0067
# Epoch 45/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0056
# Epoch 46/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0050
# Epoch 47/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0046
# Epoch 48/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0040
# Epoch 49/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0036
# Epoch 50/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.8015 - val_loss: 1.1755
# Epoch 51/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 52/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0028
# Epoch 53/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 54/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 55/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 56/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 57/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 58/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 59/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 60/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.8045 - val_loss: 1.2455
# Epoch 61/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 62/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 63/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 64/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 65/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 66/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0013
# Epoch 67/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0013
# Epoch 68/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 69/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 70/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8037 - val_loss: 1.2993
# Epoch 71/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 72/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 73/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 74/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 9.9982e-04
# Epoch 75/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 9.6246e-04
# Epoch 76/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 9.2753e-04
# Epoch 77/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 8.9556e-04
# Epoch 78/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 8.7619e-04
# Epoch 79/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 8.5052e-04
# Epoch 80/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 1.0000 - loss: 8.1903e-04 - val_accuracy: 0.8040 - val_loss: 1.3428
# Epoch 81/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 7.9458e-04
# Epoch 82/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 7.7114e-04
# Epoch 83/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 7.4932e-04
# Epoch 84/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 7.2856e-04
# Epoch 85/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 7.0400e-04
# Epoch 86/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 6.8314e-04
# Epoch 87/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 6.6566e-04
# Epoch 88/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 6.4667e-04
# Epoch 89/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 6.2851e-04
# Epoch 90/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 1.0000 - loss: 6.1372e-04 - val_accuracy: 0.8052 - val_loss: 1.3745
# Epoch 91/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 5.9835e-04
# Epoch 92/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 5.8056e-04
# Epoch 93/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 5.6576e-04
# Epoch 94/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 5.5028e-04
# Epoch 95/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 5.3651e-04
# Epoch 96/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 5.2333e-04
# Epoch 97/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 5.0679e-04
# Epoch 98/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 4.9573e-04
# Epoch 99/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 4.8082e-04
# Epoch 100/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 1.0000 - loss: 4.6968e-04 - val_accuracy: 0.8047 - val_loss: 1.4070
# Epoch 101/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 4.6035e-04
# Epoch 102/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 4.4687e-04
# Epoch 103/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 4.3346e-04
# Epoch 104/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 4.2081e-04
# Epoch 105/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 4.1045e-04
# Epoch 106/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 3.9927e-04
# Epoch 107/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 3.8843e-04
# Epoch 108/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 3.7738e-04
# Epoch 109/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 3.6788e-04
# Epoch 110/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 1.0000 - loss: 3.6006e-04 - val_accuracy: 0.8053 - val_loss: 1.4302
# Epoch 111/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 3.5045e-04
# Epoch 112/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 3.4029e-04
# Epoch 113/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 3.3260e-04
# Epoch 114/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 3.2219e-04
# Epoch 115/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 3.1390e-04
# Epoch 116/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 3.0657e-04
# Epoch 117/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 2.9958e-04
# Epoch 118/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 2.9115e-04
# Epoch 119/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 2.8360e-04
# Epoch 120/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 1.0000 - loss: 2.7675e-04 - val_accuracy: 0.8047 - val_loss: 1.4545
# Epoch 121/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 2.6969e-04
# Epoch 122/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 2.6303e-04
# Epoch 123/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 2.5737e-04
# Epoch 124/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 2.5026e-04
# Epoch 125/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 2.4482e-04
# Epoch 126/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 2.3922e-04
# Epoch 127/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 2.3361e-04
# Epoch 128/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 2.2785e-04
# Epoch 129/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 2.2317e-04
# Epoch 130/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 1.0000 - loss: 2.1945e-04 - val_accuracy: 0.8042 - val_loss: 1.4730
# Epoch 131/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 2.1439e-04
# Epoch 132/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 2.0905e-04
# Epoch 133/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 2.0347e-04
# Epoch 134/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 2.0062e-04
# Epoch 135/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 1.9489e-04
# Epoch 136/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.9195e-04
# Epoch 137/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.8939e-04
# Epoch 138/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 1.8271e-04
# Epoch 139/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.8081e-04
# Epoch 140/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 1.0000 - loss: 1.7744e-04 - val_accuracy: 0.8043 - val_loss: 1.4916
# Epoch 141/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.7202e-04
# Epoch 142/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 1.6915e-04
# Epoch 143/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 1.6525e-04
# Epoch 144/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.6172e-04
# Epoch 145/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.5835e-04
# Epoch 146/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 1.5605e-04
# Epoch 147/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.5264e-04
# Epoch 148/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.4910e-04
# Epoch 149/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 1.4684e-04
# Epoch 150/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 1.0000 - loss: 1.4322e-04 - val_accuracy: 0.8047 - val_loss: 1.5058
# Epoch 151/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.4064e-04
# Epoch 152/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.3764e-04
# Epoch 153/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.3550e-04
# Epoch 154/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 1.3305e-04
# Epoch 155/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 1.3013e-04
# Epoch 156/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 1.2756e-04
# Epoch 157/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.2567e-04
# Epoch 158/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 1.2302e-04
# Epoch 159/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.2083e-04
# Epoch 160/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 1.0000 - loss: 1.1881e-04 - val_accuracy: 0.8050 - val_loss: 1.5185
# Epoch 161/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.1631e-04
# Epoch 162/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 1.1412e-04
# Epoch 163/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 1.1219e-04
# Epoch 164/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.1031e-04
# Epoch 165/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.0875e-04
# Epoch 166/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 1.0657e-04
# Epoch 167/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 1.0495e-04
# Epoch 168/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.0295e-04
# Epoch 169/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.0123e-04
# Epoch 170/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 1.0000 - loss: 9.9330e-05 - val_accuracy: 0.8058 - val_loss: 1.5294
# Epoch 171/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 9.7474e-05
# Epoch 172/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 9.6424e-05
# Epoch 173/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 9.4638e-05
# Epoch 174/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 9.3342e-05
# Epoch 175/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 9.1553e-05
# Epoch 176/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 8.9887e-05
# Epoch 177/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 8.8071e-05
# Epoch 178/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 8.6611e-05
# Epoch 179/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 8.5339e-05
# Epoch 180/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 1.0000 - loss: 8.4100e-05 - val_accuracy: 0.8050 - val_loss: 1.5384
# Epoch 181/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 8.2579e-05
# Epoch 182/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 8.1595e-05
# Epoch 183/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 7.9814e-05
# Epoch 184/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 7.8512e-05
# Epoch 185/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 7.7896e-05
# Epoch 186/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 7.6320e-05
# Epoch 187/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 7.4999e-05
# Epoch 188/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 7.4517e-05
# Epoch 189/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 7.3348e-05
# Epoch 190/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 1.0000 - loss: 7.2166e-05 - val_accuracy: 0.8047 - val_loss: 1.5447
# Epoch 191/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 7.0902e-05
# Epoch 192/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 6.9865e-05
# Epoch 193/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 6.8702e-05
# Epoch 194/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 6.7631e-05
# Epoch 195/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 6.6787e-05
# Epoch 196/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 6.6232e-05
# Epoch 197/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 6.4910e-05
# Epoch 198/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 6.4075e-05
# Epoch 199/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 6.3090e-05
# Epoch 200/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 1.0000 - loss: 6.2330e-05 - val_accuracy: 0.8048 - val_loss: 1.5531
# Model performance:
# 	Train loss:          0.0001
# 	Train accuracy:      100.00
# 	Validation loss:     1.5531
# 	Validation accuracy: 80.48

# %% [markdown]
# ### Tumor classification in digital pathology
# #### Task 3
# In this task, we will look at a more difficult task, using the PatchCamelyon dataset. This contains tissue samples from breast lymph nodes, which could either be healthy or contain tumor tissue, i.e. this is a binary classification problem. For this reason, it is valuable to also evaluate the AU-ROC, which can be passed to Keras as an evaluation metric, 'AUC'.
#
# You are provided with the training and validation set. These have been cropped to 32x32 pixels, to make it a bit less resource demanding to train. The test set is also provided, but without labels.
#
# Your task is to setup a Keras model to achieve the best possible performance on the validation set. You are free to choose how to do this, e.g., by means of regularization and network specifications. You can, for example, use your results from Task 2 as a starting point, but you should also think around how this problem differs from the MNIST classification. For example, in this case the orientation of images has no meaning, so you can randomly flip images both horizontally and vertically. You can also, e.g., explore augmentation by means of changing the image contrast and brightness.
#
# When you are finished with your development, you should run the 'util.pred_test' (at the bottom of the cell), to produce a CSV file with predictions of the test set. The exported CSV file should be uploaded to the Kaggle challenge, as described in the lab information. You need to train the model and export a CSV file 5 times, in order to have a good estimate for your model's performance. There are no requirements on how well your model should perform, as long as it is well above random guessing (50% accuracy).

# %%
from tensorflow import keras
from tensorflow.keras import layers
import util
import data_generator
    
epochs = 10
batch_size = 128

# Load the PatchCamyleon dataset
# In this dataset, we don't have labels for the test set.
# Do your development by monitoring the validation performance,
# and when you are finished you will run predictions on the test
# set and produce a CSV file that you can upload to Kaggle.
data = data_generator.DataGenerator()
data.generate(dataset='patchcam')
data.plot()

keras.backend.clear_session()

# TODO: Build your network here
x = layers.Input(shape=data.x_train.shape[1:])
flat1  = layers.Flatten()(x)
y = layers.Dense(data.K, activation='softmax')(flat1)

model = keras.models.Model(inputs=x, outputs=y)
model.summary()

opt = keras.optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy','AUC'])
log = model.fit(data.x_train, data.y_train_oh, batch_size=batch_size, epochs=epochs, 
                validation_data=(data.x_valid, data.y_valid_oh), validation_freq=1,
                verbose=True)

util.evaluate(model, data)
util.plot_training(log)

# TODO: When you have finished your model development, you should 
# run inference on the test set and export a CSV file that can be 
# uploaded to Kaggle
#util.pred_test(model, data, name='your_submission.csv')
# Out:
# Data specification:
# 	Dataset type:           patchcam
# 	Number of classes:      2
# 	Number of channels:     3
# 	Training data shape:    (100000, 32, 32, 3)
# 	Validation data shape:  (32768, 32, 32, 3)
# 	Test data shape:        (32768, 32, 32, 3)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 3072)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 2)              │         6,146 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,146 (24.01 KB)
#  Trainable params: 6,146 (24.01 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 643us/step - AUC: 0.6248 - accuracy: 0.5953 - loss: 0.6831 - val_AUC: 0.6769 - val_accuracy: 0.6403 - val_loss: 0.6501
# Epoch 2/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step - AUC: 0.6776 - accuracy: 0.6315 - loss: 0.6466 - val_AUC: 0.6728 - val_accuracy: 0.6152 - val_loss: 0.6389
# Epoch 3/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step - AUC: 0.7088 - accuracy: 0.6549 - loss: 0.6278 - val_AUC: 0.7440 - val_accuracy: 0.6772 - val_loss: 0.6055
# Epoch 4/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - AUC: 0.7242 - accuracy: 0.6672 - loss: 0.6185 - val_AUC: 0.7411 - val_accuracy: 0.6813 - val_loss: 0.6033
# Epoch 5/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - AUC: 0.7320 - accuracy: 0.6736 - loss: 0.6147 - val_AUC: 0.7566 - val_accuracy: 0.6855 - val_loss: 0.5893
# Epoch 6/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - AUC: 0.7347 - accuracy: 0.6776 - loss: 0.6140 - val_AUC: 0.6393 - val_accuracy: 0.5885 - val_loss: 0.7007
# Epoch 7/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - AUC: 0.7440 - accuracy: 0.6849 - loss: 0.6070 - val_AUC: 0.7596 - val_accuracy: 0.6913 - val_loss: 0.5891
# Epoch 8/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - AUC: 0.7469 - accuracy: 0.6862 - loss: 0.6050 - val_AUC: 0.7463 - val_accuracy: 0.6869 - val_loss: 0.6045
# Epoch 9/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - AUC: 0.7507 - accuracy: 0.6910 - loss: 0.6031 - val_AUC: 0.7692 - val_accuracy: 0.7044 - val_loss: 0.5861
# Epoch 10/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - AUC: 0.7485 - accuracy: 0.6890 - loss: 0.6058 - val_AUC: 0.7692 - val_accuracy: 0.7029 - val_loss: 0.5871
# Model performance:
# 	Train loss:          0.5851
# 	Train accuracy:      70.68
# 	Train AUC:           0.77
# 	Validation loss:     0.5871
# 	Validation accuracy: 70.29
# 	Validation AUC:     0.77
