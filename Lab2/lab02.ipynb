# %% [markdown]
# # TNM112 -- Lab 2

# %% [markdown]
# ### Data generation
# Look through the "data_generator.py" code to understand how the dataset is generated and plotted.
#
# A dataset can be generated with a randomly selected subset of training images, and with a specified fraction used to formulate a validation set. Here, we use the MNIST dataset of handwritten digits.

# %%
import data_generator

data = data_generator.DataGenerator()
data.generate(dataset='mnist', N_valid=0.1)
data.plot()
# Out:
# Data specification:
# 	Dataset type:           mnist
# 	Number of classes:      10
# 	Number of channels:     1
# 	Training data shape:    (54000, 28, 28, 1)
# 	Validation data shape:  (6000, 28, 28, 1)
# 	Test data shape:        (10000, 28, 28, 1)

# %% [markdown]
# ### Keras CNN
# A small CNN in Keras, trained with cross-entropy loss
#
# We use the functions in 'util.py' to evaluate the model and plot the training progress.

# %%
from tensorflow import keras
from tensorflow.keras import layers
import util

keras.backend.clear_session()

model = keras.Sequential()
model.add(layers.InputLayer(input_shape=data.x_train.shape[1:]))
model.add(layers.Conv2D(4, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Conv2D(8, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(data.K, activation='softmax'))
model.summary()

opt = keras.optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
log = model.fit(data.x_train, data.y_train_oh, batch_size=128, epochs=10, 
                validation_data=(data.x_valid, data.y_valid_oh), verbose=True)

util.evaluate(model, data, final=True)
util.plot_training(log)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 28, 28, 4)      │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 4)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 14, 14, 8)      │           296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 7, 7, 8)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 392)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │         3,930 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,266 (16.66 KB)
#  Trainable params: 4,266 (16.66 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8105 - loss: 0.6419 - val_accuracy: 0.9227 - val_loss: 0.2696
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9296 - loss: 0.2315 - val_accuracy: 0.9467 - val_loss: 0.1830
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9509 - loss: 0.1638 - val_accuracy: 0.9565 - val_loss: 0.1467
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9614 - loss: 0.1297 - val_accuracy: 0.9628 - val_loss: 0.1257
# Epoch 5/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9672 - loss: 0.1101 - val_accuracy: 0.9687 - val_loss: 0.1103
# Epoch 6/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9703 - loss: 0.0988 - val_accuracy: 0.9698 - val_loss: 0.1029
# Epoch 7/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9724 - loss: 0.0906 - val_accuracy: 0.9727 - val_loss: 0.0949
# Epoch 8/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9743 - loss: 0.0832 - val_accuracy: 0.9740 - val_loss: 0.0892
# Epoch 9/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9757 - loss: 0.0781 - val_accuracy: 0.9737 - val_loss: 0.0900
# Epoch 10/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9768 - loss: 0.0741 - val_accuracy: 0.9743 - val_loss: 0.0876
# Model performance:
# 	Train loss:          0.0701
# 	Train accuracy:      97.81
# 	Test loss:           0.0731
# 	Test accuracy:       97.71

# %% [markdown]
# ### Our CNN
#
# #### Task 1
# Implement the following functions in cnn.py: 'activation', 'conv2d_layer', 'pool2d_layer', 'flatten_layer', 'dense_layer', and 'evaluate'. Additionally, compute the number of weights in the model, in the function 'setup_model'.
#
# For the 'activation' and 'dense_layer' functions you can use code that you wrote in Lab 1. For the 'evaluate' function you can use the code from Lab 1 for the accuracy. However, now we have trained with the cross-entropy loss, so you should evaluate this loss function through our CNN.
#
# When you have finished the implementation, you should be able to run this code and get the same result as with the Keras model above. However, our code is not optimized, nor parallelized, so it will be rather slow to process the full dataset. In order to facilitate comparisons when you implement the functions, please have a look in the next cell below.

# %%
import importlib
import cnn
importlib.reload(cnn)

# Get the weight matrices and biases of the trained Keras model
W, b, lname = util.get_weights(model)

# This is our implementation of a CNN, which we set to use the dataset we generated
cnn = cnn.CNN(data, verbose=True)

# Assign the weights and biases to the CNN and specify the activation function
cnn.setup_model(W, b, lname, activation='relu')

# Evaluate the model (accuracy on the training and test data)
cnn.evaluate()
# Out:
# Number of model weights:  12
# Model performance:
# sample 0 of 54000
# sample 1000 of 54000
# sample 2000 of 54000
# sample 3000 of 54000
# sample 4000 of 54000
# sample 5000 of 54000
# sample 6000 of 54000
# sample 7000 of 54000
# sample 8000 of 54000
# sample 9000 of 54000
# sample 10000 of 54000
# sample 11000 of 54000
# sample 12000 of 54000
# sample 13000 of 54000
# sample 14000 of 54000
# sample 15000 of 54000
# sample 16000 of 54000
# sample 17000 of 54000
# sample 18000 of 54000
# sample 19000 of 54000
# sample 20000 of 54000
# sample 21000 of 54000
# sample 22000 of 54000
# sample 23000 of 54000
# sample 24000 of 54000
# sample 25000 of 54000
# sample 26000 of 54000
# sample 27000 of 54000
# sample 28000 of 54000
# sample 29000 of 54000
# sample 30000 of 54000
# sample 31000 of 54000
# sample 32000 of 54000
# sample 33000 of 54000
# sample 34000 of 54000
# sample 35000 of 54000
# sample 36000 of 54000
# sample 37000 of 54000
# sample 38000 of 54000
# sample 39000 of 54000
# sample 40000 of 54000
# sample 41000 of 54000
# sample 42000 of 54000
# sample 43000 of 54000
# sample 44000 of 54000
# sample 45000 of 54000
# sample 46000 of 54000
# sample 47000 of 54000
# sample 48000 of 54000
# sample 49000 of 54000
# sample 50000 of 54000
# sample 51000 of 54000
# sample 52000 of 54000
# sample 53000 of 54000
# 	Train loss:     0.0033
# 	Train accuracy: 97.81
# sample 0 of 10000
# sample 1000 of 10000
# sample 2000 of 10000
# sample 3000 of 10000
# sample 4000 of 10000
# sample 5000 of 10000
# sample 6000 of 10000
# sample 7000 of 10000
# sample 8000 of 10000
# sample 9000 of 10000
# 	Test loss:      0.0033
# 	Test accuracy:  97.71

# %% [markdown]
# ### Evaluation of our CNN layers
#
# #### Task 1
# As part of the implementation of the different layers in 'cnn.py', you can use the below code to compare the output of a randomly initialized Keras model and our CNN, for a single image. This is fast to compute, which will be convenient to check that your layers are correctly implemented.

# %%
import numpy as np
import cnn
importlib.reload(cnn)

# Secify a test layer for comparison: 'conv', 'pool', 'flatten', or 'dense'
test_layer = 'conv'

keras.backend.clear_session()

# Keras model and input layer
model = keras.Sequential()
model.add(layers.InputLayer(input_shape=data.x_train.shape[1:]))

# Test conv layer
#   - We apply normal initialization to the bias also,
#     otherwise it would be difficult to see the impact
#     of how you apply the bias (it is initialized to 0 by default)
if test_layer == 'conv':
    model.add(layers.Conv2D(4, kernel_size=(3, 3), 
                            activation='relu', padding='same',
                            bias_initializer='normal'))
    
    # You could also test to add a second convolutional layer, to check
    # that your network maps correctly from the output channels of the
    # previous layer, to the channels of this layer
    #model.add(layers.Conv2D(4, kernel_size=(3, 3), 
    #                        activation='relu', padding='same',
    #                        bias_initializer='normal'))

# Test pooling layer
elif test_layer == 'pool':
    model.add(layers.MaxPooling2D(pool_size=(2, 2)))

# Test flattening layer
elif test_layer == 'flatten':
    model.add(layers.Flatten())

# Test dense layer
#   - We need to first flatten the image input to apply a dense layer
#   - Make sure that your flatten layer works before testing the dense layer
elif test_layer == 'dense':
    model.add(layers.Flatten())
    model.add(layers.Dense(10, activation='softmax',
                           bias_initializer='normal'))

# Test data point (you could select any other image if you want)
x = data.x_train[0]

# Keras prediction. We need ta add an extra axis, 
# since the model can run over multiple datapoints. We 
# would need this in our model also if we use used the
# 'feedforward' function instead of the 'feedforward_sample'
y1 = model.predict(x[np.newaxis,:,:,:], verbose=False)

# Prediction with our network
W, b, lname = util.get_weights(model)  # Get the Keras model weights
cnn = cnn.CNN(data)
cnn.setup_model(W, b, lname, activation='relu') # Assign weights to our model
y2 = cnn.feedforward_sample(x) # Feedforward of one single sample

print('Evaluation of %s layer:'%test_layer)

# Check that the dimensionality is correct. The Keras
# model will have an extra first dimension due to the
# batch processing
print('\tShape of Keras output:  ', y1.shape)
print('\tShape of our output:    ', y2.shape)

# Print the absolute sum of output from the Keras
# model and our model. These should be the same if the
# implementation is correct
print('\tAbs sum of Keras model: ', np.sum(np.abs(y1)))
print('\tAbs sum of our model:   ', np.sum(np.abs(y2)))

# Print the absolute difference between the Keras
# model and our model. This should be very close
# to 0 if your implementation is correct. It could be
# a very minor difference due to numerical differences 
# (e.g., difference in precision used)
print('\tAbs difference:         ', np.sum(np.abs(y1-y2)))
# Out:
# Number of model weights:  2
# Evaluation of conv layer:
# 	Shape of Keras output:   (1, 28, 28, 4)
# 	Shape of our output:     (28, 28, 4)
# 	Abs sum of Keras model:  1355.2545
# 	Abs sum of our model:    1355.2544945646077
# 	Abs difference:          5.241483449935913e-05
# /Users/emildjurson/Documents/GitHub/TNM112/venv/lib/python3.13/site-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %% [markdown]
# ### MNIST with limited training data
# #### Task 2
# In this experiment, we select a random subset from MNIST, with only 128 images. This is a very minimal dataset, but it is interesting to see how overfitting can be prevented with regularization strategies.
#
# Your task is to expand the given network with different regularization strategies. You are free to choose which combination of strategies you want to use, for example augmentation layers, dropout, weight decay, batch normalization, etc. You can also expand the network with more layers, strided convolutions, or add skip-connections to facilitate optimization. Moreover, you can experiment with the number of training epochs and the batch size.
#
# Also, note that now we have specified the Keras network in a sligthly different way. We explicitly formulate the input and output to the different layers. One motiviation for this is that it is easier if we want to, e.g., add skip-connections (checkout the layers.Add() layer in Keras).
#
# During your development, you test the performance on the validation set (util.evaluate with the flag final=False). When you have found a good setup, run evaluation on the test set (final=True). Do this for at least 5 runs and report the average and the variance across models. Since the subset of 128 images is randomly selected and the optimization is stochastic, you will get slightly different values each time. Thus, averaging is important to get a robust indication of your model's performance. You can do this manually, or you can setup a for-loop to run a sequence of trainings, where you log the evaluation results for each model.
#
# For the final results, you should aim at having an average accuracy of at least 90% (which is quite good considering that we are only training on 128 images).

# %%
# A block of convolutional layers followed by max pooling
def conv_block(x, N, channels, kernel_size, activation, padding='same'):
    for i in range(N):
        x = layers.Conv2D(channels, kernel_size=kernel_size, activation=activation, padding=padding)(x)
    return layers.MaxPooling2D(pool_size=(2, 2))(x)
    
epochs = 300
batch_size = 64

# For setting up averaging over multiple training runs
K = 5
acc = np.zeros((K,2))
for k in range(K):

# MNIST with 128 randomly selected training images
    data = data_generator.DataGenerator()
    data.generate(dataset='mnist', N_train=128)

    keras.backend.clear_session()

    x      = layers.Input(shape=data.x_train.shape[1:])

    shear = keras.layers.RandomShear(0.08, 0.08)(x)
    zoom = keras.layers.RandomZoom(0.08)(shear)
    trans = keras.layers.RandomTranslation(0.08, 0.08)(zoom)
    rot = keras.layers.RandomRotation(0.1)(trans)

    conv1  = conv_block(rot, N=2, channels=8, kernel_size=(3,3), activation='relu', padding='same')
    conv2  = conv_block(conv1, N=2, channels=16, kernel_size=(3,3), activation='relu', padding='same')
    conv3  = conv_block(conv2, N=2, channels=32, kernel_size=(3,3), activation='relu', padding='same')
    flat1  = layers.Flatten()(conv3)
    
    dense1 = layers.Dense(128, activation='relu', kernel_regularizer=keras.regularizers.L2(l2=0.001))(flat1)
    dropd1  = keras.layers.Dropout(0.2)(dense1)
    dense2 = layers.Dense(64, activation='relu', kernel_regularizer=keras.regularizers.L2(l2=0.001))(dropd1)
    dropd2  = keras.layers.Dropout(0.2)(dense2)
    y = layers.Dense(data.K, activation='softmax')(dropd2)
    
    model = keras.models.Model(inputs=x, outputs=y)
    model.summary()

    opt = keras.optimizers.Adam()
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    log = model.fit(data.x_train, data.y_train_oh, batch_size=batch_size, epochs=epochs, 
                validation_data=(data.x_valid, data.y_valid_oh), validation_freq=10,  # We don't need to evaluate at each epoch
                verbose=True)

    # util.evaluate(model, data, final=False)
    util.plot_training(log)

# When you are finished with hyper-parameter tuning, you should evaluate
# your model on the test set, and average over 5 trainings. If you want
# to do this automatically, you can setup a foor loop and store each evaluation
    acc[k,:] = util.evaluate(model, data, final=True)

print(f"Average accuracy: {np.mean(acc[:,1]):.4f} ± {np.std(acc[:,1]):.4f}")
# Out:
# Data specification:
# 	Dataset type:           mnist
# 	Number of classes:      10
# 	Number of channels:     1
# 	Training data shape:    (128, 28, 28, 1)
# 	Validation data shape:  (6000, 28, 28, 1)
# 	Test data shape:        (10000, 28, 28, 1)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_shear (RandomShear)      │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_zoom (RandomZoom)        │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_translation              │ (None, 28, 28, 1)      │             0 │
# │ (RandomTranslation)             │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_rotation                 │ (None, 28, 28, 1)      │             0 │
# │ (RandomRotation)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 28, 28, 8)      │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 28, 28, 8)      │           584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 14, 14, 16)     │         1,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 14, 14, 16)     │         2,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 7, 7, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 7, 7, 32)       │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 7, 7, 32)       │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 3, 3, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 288)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        36,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 63,938 (249.76 KB)
#  Trainable params: 63,938 (249.76 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.0781 - loss: 2.5622
# Epoch 2/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1484 - loss: 2.5474
# Epoch 3/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1797 - loss: 2.5249
# Epoch 4/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1797 - loss: 2.4961
# Epoch 5/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1875 - loss: 2.4701
# Epoch 6/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1797 - loss: 2.4377
# Epoch 7/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1875 - loss: 2.4702
# Epoch 8/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1797 - loss: 2.4730
# Epoch 9/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1719 - loss: 2.4281
# Epoch 10/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.1719 - loss: 2.4161 - val_accuracy: 0.1033 - val_loss: 2.4607
# Epoch 11/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2266 - loss: 2.3740
# Epoch 12/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.2031 - loss: 2.3719
# Epoch 13/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2656 - loss: 2.3614
# Epoch 14/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.2188 - loss: 2.3217
# Epoch 15/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2266 - loss: 2.2509
# Epoch 16/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.2734 - loss: 2.2370
# Epoch 17/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2578 - loss: 2.2478
# Epoch 18/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.2656 - loss: 2.1599
# Epoch 19/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3203 - loss: 2.1653
# Epoch 20/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.3828 - loss: 2.1510 - val_accuracy: 0.4293 - val_loss: 1.9578
# Epoch 21/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4219 - loss: 2.0182
# Epoch 22/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3828 - loss: 1.9527
# Epoch 23/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3984 - loss: 1.9309
# Epoch 24/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4766 - loss: 1.7709
# Epoch 25/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4609 - loss: 1.7755
# Epoch 26/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4688 - loss: 1.7610
# Epoch 27/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4219 - loss: 1.8022
# Epoch 28/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4297 - loss: 1.7775
# Epoch 29/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4844 - loss: 1.6329
# Epoch 30/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.4844 - loss: 1.7392 - val_accuracy: 0.5557 - val_loss: 1.4081
# Epoch 31/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4375 - loss: 1.7573
# Epoch 32/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5156 - loss: 1.6010
# Epoch 33/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5469 - loss: 1.5655
# Epoch 34/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5000 - loss: 1.5510
# Epoch 35/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5078 - loss: 1.5524
# Epoch 36/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5703 - loss: 1.4641
# Epoch 37/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4453 - loss: 1.5582
# Epoch 38/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5703 - loss: 1.5406
# Epoch 39/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5625 - loss: 1.3459
# Epoch 40/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.6172 - loss: 1.3763 - val_accuracy: 0.6960 - val_loss: 1.0612
# Epoch 41/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6250 - loss: 1.2367
# Epoch 42/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5859 - loss: 1.3476
# Epoch 43/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5703 - loss: 1.2804
# Epoch 44/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6016 - loss: 1.2639
# Epoch 45/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6406 - loss: 1.1914
# Epoch 46/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6250 - loss: 1.2478
# Epoch 47/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6406 - loss: 1.2726
# Epoch 48/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6797 - loss: 1.0828
# Epoch 49/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6719 - loss: 1.1393
# Epoch 50/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.6406 - loss: 1.1864 - val_accuracy: 0.7460 - val_loss: 0.8693
# Epoch 51/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7500 - loss: 1.0611
# Epoch 52/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6406 - loss: 1.1331
# Epoch 53/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6719 - loss: 1.0672
# Epoch 54/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6875 - loss: 1.0075
# Epoch 55/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7266 - loss: 0.9167
# Epoch 56/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7031 - loss: 1.0319
# Epoch 57/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7188 - loss: 0.9882
# Epoch 58/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7500 - loss: 0.9770
# Epoch 59/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7188 - loss: 0.9051
# Epoch 60/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.7109 - loss: 0.9906 - val_accuracy: 0.7800 - val_loss: 0.7661
# Epoch 61/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7656 - loss: 0.9111
# Epoch 62/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7578 - loss: 0.7994
# Epoch 63/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7969 - loss: 0.8401
# Epoch 64/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7500 - loss: 0.8407
# Epoch 65/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7734 - loss: 0.8042
# Epoch 66/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8281 - loss: 0.7045
# Epoch 67/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7656 - loss: 0.7975
# Epoch 68/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8125 - loss: 0.8183
# Epoch 69/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7969 - loss: 0.7433
# Epoch 70/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.7891 - loss: 0.7467 - val_accuracy: 0.8412 - val_loss: 0.6068
# Epoch 71/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7812 - loss: 0.8171
# Epoch 72/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8359 - loss: 0.7140
# Epoch 73/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8438 - loss: 0.6269
# Epoch 74/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8438 - loss: 0.6610
# Epoch 75/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7969 - loss: 0.6726
# Epoch 76/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8359 - loss: 0.6472
# Epoch 77/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8438 - loss: 0.5979
# Epoch 78/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8359 - loss: 0.5962
# Epoch 79/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8047 - loss: 0.7156
# Epoch 80/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.8594 - loss: 0.5613 - val_accuracy: 0.8448 - val_loss: 0.6108
# Epoch 81/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7891 - loss: 0.7163
# Epoch 82/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8828 - loss: 0.5091
# Epoch 83/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7969 - loss: 0.7225
# Epoch 84/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8828 - loss: 0.5237
# Epoch 85/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8438 - loss: 0.5531
# Epoch 86/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7969 - loss: 0.5990
# Epoch 87/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8672 - loss: 0.5648
# Epoch 88/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7812 - loss: 0.6943
# Epoch 89/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8750 - loss: 0.6003
# Epoch 90/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.8984 - loss: 0.4797 - val_accuracy: 0.8695 - val_loss: 0.5551
# Epoch 91/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8281 - loss: 0.5623
# Epoch 92/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9141 - loss: 0.4332
# Epoch 93/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8359 - loss: 0.5654
# Epoch 94/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8828 - loss: 0.4433
# Epoch 95/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8984 - loss: 0.4943
# Epoch 96/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8672 - loss: 0.5454
# Epoch 97/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9219 - loss: 0.4013
# Epoch 98/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8438 - loss: 0.5525
# Epoch 99/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8750 - loss: 0.4528
# Epoch 100/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.8438 - loss: 0.5896 - val_accuracy: 0.8657 - val_loss: 0.6226
# Epoch 101/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8594 - loss: 0.5328
# Epoch 102/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8750 - loss: 0.4694
# Epoch 103/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8750 - loss: 0.5061
# Epoch 104/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8750 - loss: 0.4366
# Epoch 105/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8906 - loss: 0.4853
# Epoch 106/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8750 - loss: 0.4916
# Epoch 107/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9062 - loss: 0.4057
# Epoch 108/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8281 - loss: 0.6069
# Epoch 109/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8594 - loss: 0.5333
# Epoch 110/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.8906 - loss: 0.4095 - val_accuracy: 0.8698 - val_loss: 0.5611
# Epoch 111/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8984 - loss: 0.3936
# Epoch 112/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9062 - loss: 0.4142
# Epoch 113/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9062 - loss: 0.4031
# Epoch 114/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9141 - loss: 0.4077
# Epoch 115/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8750 - loss: 0.5080
# Epoch 116/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8750 - loss: 0.4536
# Epoch 117/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9375 - loss: 0.3687
# Epoch 118/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8984 - loss: 0.3593
# Epoch 119/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9297 - loss: 0.3526
# Epoch 120/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.8750 - loss: 0.4708 - val_accuracy: 0.8892 - val_loss: 0.5455
# Epoch 121/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9219 - loss: 0.3333
# Epoch 122/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9141 - loss: 0.3681
# Epoch 123/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8828 - loss: 0.3769
# Epoch 124/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9141 - loss: 0.4076
# Epoch 125/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8906 - loss: 0.4039
# Epoch 126/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8906 - loss: 0.4179
# Epoch 127/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9062 - loss: 0.3907
# Epoch 128/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8672 - loss: 0.4721
# Epoch 129/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8594 - loss: 0.5520
# Epoch 130/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.8828 - loss: 0.3923 - val_accuracy: 0.8667 - val_loss: 0.6566
# Epoch 131/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8984 - loss: 0.4698
# Epoch 132/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9062 - loss: 0.4188
# Epoch 133/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9375 - loss: 0.3918
# Epoch 134/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9375 - loss: 0.3501
# Epoch 135/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9375 - loss: 0.3926
# Epoch 136/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9062 - loss: 0.3950
# Epoch 137/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9688 - loss: 0.2633
# Epoch 138/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9531 - loss: 0.2919
# Epoch 139/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9375 - loss: 0.3284
# Epoch 140/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9375 - loss: 0.3435 - val_accuracy: 0.8925 - val_loss: 0.5179
# Epoch 141/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9297 - loss: 0.3642
# Epoch 142/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9062 - loss: 0.4849
# Epoch 143/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9453 - loss: 0.3256
# Epoch 144/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9141 - loss: 0.3474
# Epoch 145/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9609 - loss: 0.2489
# Epoch 146/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9219 - loss: 0.3269
# Epoch 147/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9297 - loss: 0.3455
# Epoch 148/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9219 - loss: 0.3332
# Epoch 149/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9375 - loss: 0.2699
# Epoch 150/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9609 - loss: 0.2419 - val_accuracy: 0.9000 - val_loss: 0.5423
# Epoch 151/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9766 - loss: 0.2545
# Epoch 152/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9531 - loss: 0.2865
# Epoch 153/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9062 - loss: 0.3600
# Epoch 154/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9453 - loss: 0.2946
# Epoch 155/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9219 - loss: 0.3535
# Epoch 156/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9531 - loss: 0.2937
# Epoch 157/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9375 - loss: 0.3042
# Epoch 158/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9375 - loss: 0.3145
# Epoch 159/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9453 - loss: 0.2759
# Epoch 160/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9219 - loss: 0.3336 - val_accuracy: 0.8737 - val_loss: 0.6372
# Epoch 161/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9688 - loss: 0.2373
# Epoch 162/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9609 - loss: 0.2892
# Epoch 163/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9297 - loss: 0.3246
# Epoch 164/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9297 - loss: 0.3093
# Epoch 165/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9609 - loss: 0.2317
# Epoch 166/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9297 - loss: 0.3641
# Epoch 167/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9297 - loss: 0.3130
# Epoch 168/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9766 - loss: 0.2256
# Epoch 169/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9688 - loss: 0.2287
# Epoch 170/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9609 - loss: 0.2529 - val_accuracy: 0.8807 - val_loss: 0.6203
# Epoch 171/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9375 - loss: 0.3245
# Epoch 172/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9531 - loss: 0.2439
# Epoch 173/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9531 - loss: 0.2201
# Epoch 174/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9688 - loss: 0.2345
# Epoch 175/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9609 - loss: 0.2311
# Epoch 176/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9453 - loss: 0.3070
# Epoch 177/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9375 - loss: 0.3169
# Epoch 178/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9609 - loss: 0.2394
# Epoch 179/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9609 - loss: 0.2794
# Epoch 180/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.9219 - loss: 0.3401 - val_accuracy: 0.8895 - val_loss: 0.6209
# Epoch 181/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9688 - loss: 0.2714
# Epoch 182/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9766 - loss: 0.2422
# Epoch 183/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9453 - loss: 0.2640
# Epoch 184/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9922 - loss: 0.1998
# Epoch 185/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9688 - loss: 0.2132
# Epoch 186/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9844 - loss: 0.1792
# Epoch 187/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9609 - loss: 0.2701
# Epoch 188/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9531 - loss: 0.2483
# Epoch 189/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9531 - loss: 0.2424
# Epoch 190/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9141 - loss: 0.3082 - val_accuracy: 0.8882 - val_loss: 0.6197
# Epoch 191/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9688 - loss: 0.2578
# Epoch 192/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9375 - loss: 0.2521
# Epoch 193/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9688 - loss: 0.2504
# Epoch 194/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9375 - loss: 0.3095
# Epoch 195/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9453 - loss: 0.2541
# Epoch 196/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9531 - loss: 0.2251
# Epoch 197/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9609 - loss: 0.2414
# Epoch 198/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9531 - loss: 0.2581
# Epoch 199/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9219 - loss: 0.2971
# Epoch 200/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9844 - loss: 0.1892 - val_accuracy: 0.9085 - val_loss: 0.5310
# Epoch 201/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9609 - loss: 0.2452
# Epoch 202/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9297 - loss: 0.2768
# Epoch 203/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9219 - loss: 0.3035
# Epoch 204/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9688 - loss: 0.2533
# Epoch 205/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9453 - loss: 0.3460
# Epoch 206/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9688 - loss: 0.2146
# Epoch 207/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9453 - loss: 0.3129
# Epoch 208/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9609 - loss: 0.2641
# Epoch 209/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9922 - loss: 0.1905
# Epoch 210/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9688 - loss: 0.2066 - val_accuracy: 0.9038 - val_loss: 0.5901
# Epoch 211/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9297 - loss: 0.3392
# Epoch 212/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9609 - loss: 0.3180
# Epoch 213/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9688 - loss: 0.2688
# Epoch 214/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9453 - loss: 0.2574
# Epoch 215/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9453 - loss: 0.2793
# Epoch 216/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9609 - loss: 0.2373
# Epoch 217/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9766 - loss: 0.2062
# Epoch 218/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9531 - loss: 0.2829
# Epoch 219/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9609 - loss: 0.2322
# Epoch 220/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.9375 - loss: 0.3001 - val_accuracy: 0.8758 - val_loss: 0.7216
# Epoch 221/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9688 - loss: 0.2068
# Epoch 222/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9375 - loss: 0.3168
# Epoch 223/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9766 - loss: 0.1894
# Epoch 224/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9453 - loss: 0.2748
# Epoch 225/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9609 - loss: 0.2353
# Epoch 226/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9375 - loss: 0.3384
# Epoch 227/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9609 - loss: 0.2204
# Epoch 228/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9531 - loss: 0.2835
# Epoch 229/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9922 - loss: 0.1760
# Epoch 230/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9844 - loss: 0.1832 - val_accuracy: 0.8888 - val_loss: 0.6634
# Epoch 231/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9531 - loss: 0.2409
# Epoch 232/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9531 - loss: 0.2354
# Epoch 233/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9688 - loss: 0.2451
# Epoch 234/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9766 - loss: 0.2048
# Epoch 235/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9609 - loss: 0.2231
# Epoch 236/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9609 - loss: 0.2049
# Epoch 237/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9844 - loss: 0.1784
# Epoch 238/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9531 - loss: 0.2454
# Epoch 239/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9766 - loss: 0.1995
# Epoch 240/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 1.0000 - loss: 0.1439 - val_accuracy: 0.9010 - val_loss: 0.6598
# Epoch 241/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9609 - loss: 0.2143
# Epoch 242/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9688 - loss: 0.2450
# Epoch 243/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9766 - loss: 0.1929
# Epoch 244/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9609 - loss: 0.2003
# Epoch 245/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9688 - loss: 0.2026
# Epoch 246/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9766 - loss: 0.1865
# Epoch 247/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9766 - loss: 0.1705
# Epoch 248/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9609 - loss: 0.3359
# Epoch 249/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9375 - loss: 0.2577
# Epoch 250/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9844 - loss: 0.1770 - val_accuracy: 0.8998 - val_loss: 0.6439
# Epoch 251/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9766 - loss: 0.1787
# Epoch 252/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9609 - loss: 0.2236
# Epoch 253/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9766 - loss: 0.1853
# Epoch 254/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9609 - loss: 0.2082
# Epoch 255/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9844 - loss: 0.1750
# Epoch 256/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9766 - loss: 0.2260
# Epoch 257/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9766 - loss: 0.1923
# Epoch 258/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9609 - loss: 0.2032
# Epoch 259/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9609 - loss: 0.2271
# Epoch 260/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9766 - loss: 0.2010 - val_accuracy: 0.8825 - val_loss: 0.6817
# Epoch 261/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9531 - loss: 0.2710
# Epoch 262/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9609 - loss: 0.2045
# Epoch 263/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9688 - loss: 0.2228
# Epoch 264/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9297 - loss: 0.3039
# Epoch 265/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9297 - loss: 0.2778
# Epoch 266/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9609 - loss: 0.2662
# Epoch 267/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9922 - loss: 0.1683
# Epoch 268/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9531 - loss: 0.2227
# Epoch 269/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9844 - loss: 0.2034
# Epoch 270/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.9609 - loss: 0.2531 - val_accuracy: 0.9072 - val_loss: 0.5707
# Epoch 271/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9844 - loss: 0.1720
# Epoch 272/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9766 - loss: 0.1909
# Epoch 273/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9844 - loss: 0.1658
# Epoch 274/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9297 - loss: 0.3324
# Epoch 275/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9766 - loss: 0.1914
# Epoch 276/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9766 - loss: 0.1699
# Epoch 277/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9688 - loss: 0.2179
# Epoch 278/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9531 - loss: 0.2413
# Epoch 279/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9922 - loss: 0.1460
# Epoch 280/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.9922 - loss: 0.1608 - val_accuracy: 0.9035 - val_loss: 0.5915
# Epoch 281/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9766 - loss: 0.1650
# Epoch 282/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9688 - loss: 0.1984
# Epoch 283/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9609 - loss: 0.3091
# Epoch 284/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9688 - loss: 0.2120
# Epoch 285/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9688 - loss: 0.2581
# Epoch 286/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9844 - loss: 0.1983
# Epoch 287/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9688 - loss: 0.1746
# Epoch 288/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9609 - loss: 0.1941
# Epoch 289/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9844 - loss: 0.2066
# Epoch 290/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9766 - loss: 0.1760 - val_accuracy: 0.9050 - val_loss: 0.6108
# Epoch 291/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9844 - loss: 0.1578
# Epoch 292/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9453 - loss: 0.2477
# Epoch 293/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9766 - loss: 0.1809
# Epoch 294/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9688 - loss: 0.1881
# Epoch 295/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9922 - loss: 0.1604
# Epoch 296/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.1523
# Epoch 297/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9922 - loss: 0.1594
# Epoch 298/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9453 - loss: 0.2838
# Epoch 299/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9844 - loss: 0.1753
# Epoch 300/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.9844 - loss: 0.1678 - val_accuracy: 0.9118 - val_loss: 0.6234
# Model performance:
# 	Train loss:          0.1134
# 	Train accuracy:      100.00
# 	Test loss:           0.6361
# 	Test accuracy:       91.04
# Data specification:
# 	Dataset type:           mnist
# 	Number of classes:      10
# 	Number of channels:     1
# 	Training data shape:    (128, 28, 28, 1)
# 	Validation data shape:  (6000, 28, 28, 1)
# 	Test data shape:        (10000, 28, 28, 1)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_shear (RandomShear)      │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_zoom (RandomZoom)        │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_translation              │ (None, 28, 28, 1)      │             0 │
# │ (RandomTranslation)             │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_rotation                 │ (None, 28, 28, 1)      │             0 │
# │ (RandomRotation)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 28, 28, 8)      │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 28, 28, 8)      │           584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 14, 14, 16)     │         1,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 14, 14, 16)     │         2,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 7, 7, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 7, 7, 32)       │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 7, 7, 32)       │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 3, 3, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 288)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        36,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 63,938 (249.76 KB)
#  Trainable params: 63,938 (249.76 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.0625 - loss: 2.5710
# Epoch 2/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1172 - loss: 2.5472
# Epoch 3/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1172 - loss: 2.5397
# Epoch 4/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1328 - loss: 2.5064
# Epoch 5/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1484 - loss: 2.5026
# Epoch 6/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1641 - loss: 2.4786
# Epoch 7/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1328 - loss: 2.4762
# Epoch 8/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1562 - loss: 2.4637
# Epoch 9/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1641 - loss: 2.4494
# Epoch 10/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.1953 - loss: 2.4383 - val_accuracy: 0.0820 - val_loss: 2.5356
# Epoch 11/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1328 - loss: 2.4270
# Epoch 12/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1719 - loss: 2.4182
# Epoch 13/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1875 - loss: 2.4182
# Epoch 14/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1562 - loss: 2.4069
# Epoch 15/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1328 - loss: 2.4173
# Epoch 16/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1484 - loss: 2.3914
# Epoch 17/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2422 - loss: 2.3832
# Epoch 18/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2422 - loss: 2.3410
# Epoch 19/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2812 - loss: 2.3186
# Epoch 20/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.2578 - loss: 2.2891 - val_accuracy: 0.3675 - val_loss: 2.3138
# Epoch 21/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2656 - loss: 2.2651
# Epoch 22/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2578 - loss: 2.2470
# Epoch 23/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3672 - loss: 2.1181
# Epoch 24/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3438 - loss: 2.0379
# Epoch 25/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3359 - loss: 2.0120
# Epoch 26/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3359 - loss: 1.9637
# Epoch 27/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4297 - loss: 1.8494
# Epoch 28/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3672 - loss: 1.8581
# Epoch 29/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4922 - loss: 1.6216
# Epoch 30/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.4375 - loss: 1.7453 - val_accuracy: 0.5373 - val_loss: 1.5147
# Epoch 31/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5156 - loss: 1.6134
# Epoch 32/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4922 - loss: 1.5725
# Epoch 33/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5547 - loss: 1.4849
# Epoch 34/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5391 - loss: 1.4870
# Epoch 35/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5156 - loss: 1.5490
# Epoch 36/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5391 - loss: 1.3421
# Epoch 37/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5547 - loss: 1.3249
# Epoch 38/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5000 - loss: 1.5456
# Epoch 39/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6172 - loss: 1.2541
# Epoch 40/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.5234 - loss: 1.4293 - val_accuracy: 0.6863 - val_loss: 1.0238
# Epoch 41/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6172 - loss: 1.2321
# Epoch 42/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6797 - loss: 1.0993
# Epoch 43/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6562 - loss: 1.0752
# Epoch 44/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7031 - loss: 1.0724
# Epoch 45/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6484 - loss: 1.1583
# Epoch 46/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6875 - loss: 1.1228
# Epoch 47/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6484 - loss: 1.1293
# Epoch 48/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7031 - loss: 1.0485
# Epoch 49/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6875 - loss: 1.0663
# Epoch 50/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.7344 - loss: 0.8820 - val_accuracy: 0.8047 - val_loss: 0.7358
# Epoch 51/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7031 - loss: 0.9262
# Epoch 52/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7344 - loss: 0.8498
# Epoch 53/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7500 - loss: 0.9097
# Epoch 54/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7031 - loss: 0.9501
# Epoch 55/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7656 - loss: 0.8122
# Epoch 56/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7578 - loss: 0.9218
# Epoch 57/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7188 - loss: 0.9515
# Epoch 58/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7422 - loss: 0.8586
# Epoch 59/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7734 - loss: 0.8437
# Epoch 60/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.7891 - loss: 0.7527 - val_accuracy: 0.8542 - val_loss: 0.5860
# Epoch 61/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7500 - loss: 0.8348
# Epoch 62/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7188 - loss: 0.8142
# Epoch 63/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7969 - loss: 0.7108
# Epoch 64/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7578 - loss: 0.8524
# Epoch 65/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7812 - loss: 0.7877
# Epoch 66/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8203 - loss: 0.5905
# Epoch 67/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7656 - loss: 0.7605
# Epoch 68/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8125 - loss: 0.7051
# Epoch 69/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8047 - loss: 0.7677
# Epoch 70/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.8516 - loss: 0.6023 - val_accuracy: 0.8538 - val_loss: 0.6118
# Epoch 71/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8203 - loss: 0.6516
# Epoch 72/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8359 - loss: 0.6162
# Epoch 73/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8438 - loss: 0.5477
# Epoch 74/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7969 - loss: 0.6617
# Epoch 75/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8203 - loss: 0.6206
# Epoch 76/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7734 - loss: 0.7640
# Epoch 77/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7812 - loss: 0.6890
# Epoch 78/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8672 - loss: 0.5542
# Epoch 79/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8672 - loss: 0.6064
# Epoch 80/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.8359 - loss: 0.5787 - val_accuracy: 0.8732 - val_loss: 0.5498
# Epoch 81/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8750 - loss: 0.5644
# Epoch 82/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7734 - loss: 0.7105
# Epoch 83/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8516 - loss: 0.5935
# Epoch 84/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8438 - loss: 0.5818
# Epoch 85/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8438 - loss: 0.5463
# Epoch 86/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8516 - loss: 0.5221
# Epoch 87/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8047 - loss: 0.6047
# Epoch 88/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8594 - loss: 0.6166
# Epoch 89/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8359 - loss: 0.5329
# Epoch 90/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.8906 - loss: 0.4648 - val_accuracy: 0.8708 - val_loss: 0.5738
# Epoch 91/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8750 - loss: 0.5634
# Epoch 92/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8516 - loss: 0.5534
# Epoch 93/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8594 - loss: 0.6457
# Epoch 94/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8438 - loss: 0.5107
# Epoch 95/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8438 - loss: 0.5236
# Epoch 96/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8672 - loss: 0.5799
# Epoch 97/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9141 - loss: 0.4348
# Epoch 98/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8516 - loss: 0.6218
# Epoch 99/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8828 - loss: 0.4918
# Epoch 100/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.8828 - loss: 0.4724 - val_accuracy: 0.8300 - val_loss: 0.6961
# Epoch 101/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8672 - loss: 0.5023
# Epoch 102/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8750 - loss: 0.4211
# Epoch 103/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8281 - loss: 0.5339
# Epoch 104/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8672 - loss: 0.6138
# Epoch 105/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8594 - loss: 0.4494
# Epoch 106/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7969 - loss: 0.5158
# Epoch 107/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8984 - loss: 0.4118
# Epoch 108/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8984 - loss: 0.5272
# Epoch 109/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8359 - loss: 0.5437
# Epoch 110/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.8047 - loss: 0.6458 - val_accuracy: 0.8872 - val_loss: 0.5364
# Epoch 111/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9375 - loss: 0.3599
# Epoch 112/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8984 - loss: 0.4653
# Epoch 113/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8984 - loss: 0.4376
# Epoch 114/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9453 - loss: 0.3755
# Epoch 115/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8594 - loss: 0.4489
# Epoch 116/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9297 - loss: 0.3509
# Epoch 117/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9375 - loss: 0.3492
# Epoch 118/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8828 - loss: 0.4381
# Epoch 119/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8672 - loss: 0.4881
# Epoch 120/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9219 - loss: 0.3239 - val_accuracy: 0.8877 - val_loss: 0.5544
# Epoch 121/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8594 - loss: 0.5277
# Epoch 122/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8828 - loss: 0.4060
# Epoch 123/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8750 - loss: 0.5622
# Epoch 124/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9219 - loss: 0.3611
# Epoch 125/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8750 - loss: 0.4485
# Epoch 126/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9062 - loss: 0.4000
# Epoch 127/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8984 - loss: 0.3900
# Epoch 128/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9297 - loss: 0.3349
# Epoch 129/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8750 - loss: 0.5400
# Epoch 130/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9141 - loss: 0.3469 - val_accuracy: 0.8797 - val_loss: 0.5692
# Epoch 131/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8984 - loss: 0.3982
# Epoch 132/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9062 - loss: 0.4569
# Epoch 133/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9297 - loss: 0.3562
# Epoch 134/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9062 - loss: 0.4317
# Epoch 135/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8984 - loss: 0.3738
# Epoch 136/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9141 - loss: 0.3756
# Epoch 137/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9141 - loss: 0.3610
# Epoch 138/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8984 - loss: 0.3869
# Epoch 139/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9375 - loss: 0.3591
# Epoch 140/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.9453 - loss: 0.3122 - val_accuracy: 0.8750 - val_loss: 0.6218
# Epoch 141/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8750 - loss: 0.4719
# Epoch 142/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8828 - loss: 0.4498
# Epoch 143/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9062 - loss: 0.3536
# Epoch 144/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9141 - loss: 0.3869
# Epoch 145/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9375 - loss: 0.3159
# Epoch 146/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8672 - loss: 0.4546
# Epoch 147/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9062 - loss: 0.3510
# Epoch 148/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9688 - loss: 0.3040
# ...
# Epoch 126/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8828 - loss: 0.3934
# Epoch 127/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9375 - loss: 0.3210
# Epoch 128/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8984 - loss: 0.4430
# Epoch 129/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9219 - loss: 0.3433
# Epoch 130/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.8828 - loss: 0.3795 - val_accuracy: 0.9210 - val_loss: 0.3767
# Epoch 131/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8828 - loss: 0.3699
# Epoch 132/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8672 - loss: 0.3931
# Epoch 133/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9375 - loss: 0.3085
# Epoch 134/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9141 - loss: 0.3437
# Epoch 135/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8984 - loss: 0.4019
# Epoch 136/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9297 - loss: 0.3959
# Epoch 137/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9297 - loss: 0.3589
# Epoch 138/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9531 - loss: 0.2473
# Epoch 139/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9297 - loss: 0.3848
# Epoch 140/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.8906 - loss: 0.4450 - val_accuracy: 0.9182 - val_loss: 0.3994
# Epoch 141/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9141 - loss: 0.3980
# Epoch 142/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9219 - loss: 0.3574
# Epoch 143/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9141 - loss: 0.3181
# Epoch 144/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8984 - loss: 0.4174
# Epoch 145/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9375 - loss: 0.2671
# Epoch 146/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9141 - loss: 0.4067
# Epoch 147/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9375 - loss: 0.2609
# Epoch 148/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9531 - loss: 0.2604
# Epoch 149/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9688 - loss: 0.2366
# Epoch 150/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.9297 - loss: 0.3030 - val_accuracy: 0.9242 - val_loss: 0.3694
# Epoch 151/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8984 - loss: 0.3582
# Epoch 152/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9453 - loss: 0.2451
# Epoch 153/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9531 - loss: 0.2281
# Epoch 154/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9453 - loss: 0.2970
# Epoch 155/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9531 - loss: 0.2494
# Epoch 156/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9609 - loss: 0.2436
# Epoch 157/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9609 - loss: 0.2232
# Epoch 158/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.2268
# Epoch 159/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9688 - loss: 0.2194
# Epoch 160/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.9531 - loss: 0.2610 - val_accuracy: 0.9227 - val_loss: 0.3950
# Epoch 161/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9297 - loss: 0.3322
# Epoch 162/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9531 - loss: 0.2340
# Epoch 163/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9531 - loss: 0.2366
# Epoch 164/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9688 - loss: 0.2233
# Epoch 165/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9531 - loss: 0.2074
# Epoch 166/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9141 - loss: 0.3554
# Epoch 167/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9531 - loss: 0.3351
# Epoch 168/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9375 - loss: 0.2541
# Epoch 169/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9141 - loss: 0.3204
# Epoch 170/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.8984 - loss: 0.3683 - val_accuracy: 0.9283 - val_loss: 0.3765
# Epoch 171/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9688 - loss: 0.2358
# Epoch 172/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9688 - loss: 0.2090
# Epoch 173/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9375 - loss: 0.3391
# Epoch 174/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9531 - loss: 0.2536
# Epoch 175/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9297 - loss: 0.2763
# Epoch 176/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9688 - loss: 0.2911
# Epoch 177/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9297 - loss: 0.2814
# Epoch 178/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9453 - loss: 0.2635
# Epoch 179/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9609 - loss: 0.2636
# Epoch 180/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.9375 - loss: 0.3281 - val_accuracy: 0.9233 - val_loss: 0.3857
# Epoch 181/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9531 - loss: 0.2707
# Epoch 182/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9375 - loss: 0.2818
# Epoch 183/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9141 - loss: 0.3325
# Epoch 184/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9141 - loss: 0.4330
# Epoch 185/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9453 - loss: 0.2719
# Epoch 186/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9453 - loss: 0.3784
# Epoch 187/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9297 - loss: 0.3018
# Epoch 188/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9609 - loss: 0.2070
# Epoch 189/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9609 - loss: 0.2317
# Epoch 190/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9688 - loss: 0.2230 - val_accuracy: 0.9325 - val_loss: 0.3511
# Epoch 191/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9531 - loss: 0.2427
# Epoch 192/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9609 - loss: 0.2133
# Epoch 193/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9609 - loss: 0.2476
# Epoch 194/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9766 - loss: 0.1912
# Epoch 195/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9375 - loss: 0.2480
# Epoch 196/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9453 - loss: 0.3028
# Epoch 197/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9688 - loss: 0.1822
# Epoch 198/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9531 - loss: 0.2351
# Epoch 199/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9531 - loss: 0.2150
# Epoch 200/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.9375 - loss: 0.2474 - val_accuracy: 0.9305 - val_loss: 0.3777
# Epoch 201/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9375 - loss: 0.2387
# Epoch 202/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9531 - loss: 0.2357
# Epoch 203/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9688 - loss: 0.1931
# Epoch 204/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9766 - loss: 0.1930
# Epoch 205/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9609 - loss: 0.2262
# Epoch 206/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9766 - loss: 0.1743
# Epoch 207/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9609 - loss: 0.2318
# Epoch 208/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9922 - loss: 0.1600
# Epoch 209/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9688 - loss: 0.2027
# Epoch 210/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.9922 - loss: 0.1668 - val_accuracy: 0.9342 - val_loss: 0.3705
# Epoch 211/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9609 - loss: 0.2032
# Epoch 212/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9766 - loss: 0.1757
# Epoch 213/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9688 - loss: 0.1952
# Epoch 214/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9688 - loss: 0.2412
# Epoch 215/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9922 - loss: 0.1473
# Epoch 216/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9609 - loss: 0.2196
# Epoch 217/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9453 - loss: 0.2079
# Epoch 218/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9531 - loss: 0.2111
# Epoch 219/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9844 - loss: 0.2159
# Epoch 220/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.9844 - loss: 0.1486 - val_accuracy: 0.9243 - val_loss: 0.4116
# Epoch 221/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9688 - loss: 0.1778
# Epoch 222/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9453 - loss: 0.2069
# Epoch 223/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9453 - loss: 0.2561
# Epoch 224/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9688 - loss: 0.1801
# Epoch 225/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9453 - loss: 0.2642
# Epoch 226/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9609 - loss: 0.2188
# Epoch 227/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9844 - loss: 0.1634
# Epoch 228/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9531 - loss: 0.1994
# Epoch 229/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9297 - loss: 0.2345
# Epoch 230/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.9766 - loss: 0.1721 - val_accuracy: 0.9223 - val_loss: 0.4172
# Epoch 231/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.1360
# Epoch 232/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9609 - loss: 0.2635
# Epoch 233/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9766 - loss: 0.1630
# Epoch 234/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9609 - loss: 0.1993
# Epoch 235/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9609 - loss: 0.2056
# Epoch 236/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9844 - loss: 0.1621
# Epoch 237/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9688 - loss: 0.2146
# Epoch 238/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9766 - loss: 0.1823
# Epoch 239/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9766 - loss: 0.2010
# Epoch 240/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.9766 - loss: 0.1530 - val_accuracy: 0.9333 - val_loss: 0.3883
# Epoch 241/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9844 - loss: 0.1728
# Epoch 242/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9609 - loss: 0.1855
# Epoch 243/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9609 - loss: 0.2029
# Epoch 244/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9766 - loss: 0.1584
# Epoch 245/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.1511
# Epoch 246/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9922 - loss: 0.1335
# Epoch 247/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9766 - loss: 0.1716
# Epoch 248/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9922 - loss: 0.1365
# Epoch 249/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9609 - loss: 0.3050
# Epoch 250/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.9844 - loss: 0.1797 - val_accuracy: 0.9330 - val_loss: 0.4073
# Epoch 251/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9531 - loss: 0.2327
# Epoch 252/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9375 - loss: 0.2596
# Epoch 253/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.1452
# Epoch 254/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9375 - loss: 0.2570
# Epoch 255/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9766 - loss: 0.2274
# Epoch 256/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9766 - loss: 0.1687
# Epoch 257/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9766 - loss: 0.1738
# Epoch 258/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9922 - loss: 0.1388
# Epoch 259/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9609 - loss: 0.1863
# Epoch 260/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.9688 - loss: 0.2285 - val_accuracy: 0.9325 - val_loss: 0.3904
# Epoch 261/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9844 - loss: 0.1395
# Epoch 262/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9844 - loss: 0.1513
# Epoch 263/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9766 - loss: 0.1792
# Epoch 264/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9922 - loss: 0.1476
# Epoch 265/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9766 - loss: 0.1736
# Epoch 266/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9766 - loss: 0.1935
# Epoch 267/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9922 - loss: 0.1512
# Epoch 268/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9844 - loss: 0.1575
# Epoch 269/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9844 - loss: 0.1360
# Epoch 270/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9922 - loss: 0.1509 - val_accuracy: 0.9340 - val_loss: 0.4060
# Epoch 271/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9688 - loss: 0.1874
# Epoch 272/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9688 - loss: 0.1610
# Epoch 273/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9922 - loss: 0.1590
# Epoch 274/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9922 - loss: 0.1709
# Epoch 275/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9844 - loss: 0.1513
# Epoch 276/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9844 - loss: 0.1429
# Epoch 277/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.1230
# Epoch 278/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9688 - loss: 0.1713
# Epoch 279/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9688 - loss: 0.1994
# Epoch 280/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.9922 - loss: 0.1273 - val_accuracy: 0.9375 - val_loss: 0.3887
# Epoch 281/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9531 - loss: 0.2203
# Epoch 282/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9609 - loss: 0.1829
# Epoch 283/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9844 - loss: 0.1721
# Epoch 284/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9766 - loss: 0.1544
# Epoch 285/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9844 - loss: 0.1381
# Epoch 286/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9844 - loss: 0.1481
# Epoch 287/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9609 - loss: 0.1914
# Epoch 288/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9688 - loss: 0.1554
# Epoch 289/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9766 - loss: 0.1566
# Epoch 290/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.9688 - loss: 0.2104 - val_accuracy: 0.9320 - val_loss: 0.4016
# Epoch 291/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9688 - loss: 0.1924
# Epoch 292/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9609 - loss: 0.2055
# Epoch 293/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9688 - loss: 0.1857
# Epoch 294/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9844 - loss: 0.1482
# Epoch 295/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9766 - loss: 0.1768
# Epoch 296/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9844 - loss: 0.1542
# Epoch 297/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9844 - loss: 0.1558
# Epoch 298/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9922 - loss: 0.1472
# Epoch 299/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9375 - loss: 0.2152
# Epoch 300/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.9766 - loss: 0.2693 - val_accuracy: 0.9398 - val_loss: 0.3874
# Model performance:
# 	Train loss:          0.0995
# 	Train accuracy:      100.00
# 	Test loss:           0.3505
# 	Test accuracy:       94.39
# Average accuracy: 0.9167 ± 0.0150

# %% [markdown]
# ### Tumor classification in digital pathology
# #### Task 3
# In this task, we will look at a more difficult task, using the PatchCamelyon dataset. This contains tissue samples from breast lymph nodes, which could either be healthy or contain tumor tissue, i.e. this is a binary classification problem. For this reason, it is valuable to also evaluate the AU-ROC, which can be passed to Keras as an evaluation metric, 'AUC'.
#
# You are provided with the training and validation set. These have been cropped to 32x32 pixels, to make it a bit less resource demanding to train. The test set is also provided, but without labels.
#
# Your task is to setup a Keras model to achieve the best possible performance on the validation set. You are free to choose how to do this, e.g., by means of regularization and network specifications. You can, for example, use your results from Task 2 as a starting point, but you should also think around how this problem differs from the MNIST classification. For example, in this case the orientation of images has no meaning, so you can randomly flip images both horizontally and vertically. You can also, e.g., explore augmentation by means of changing the image contrast and brightness.
#
# When you are finished with your development, you should run the 'util.pred_test' (at the bottom of the cell), to produce a CSV file with predictions of the test set. The exported CSV file should be uploaded to the Kaggle challenge, as described in the lab information. You need to train the model and export a CSV file 5 times, in order to have a good estimate for your model's performance. There are no requirements on how well your model should perform, as long as it is well above random guessing (50% accuracy).

# %%
from tensorflow import keras
from tensorflow.keras import layers
import util
import data_generator
    
epochs = 10
batch_size = 64

# Load the PatchCamyleon dataset
# In this dataset, we don't have labels for the test set.
# Do your development by monitoring the validation performance,
# and when you are finished you will run predictions on the test
# set and produce a CSV file that you can upload to Kaggle.
data = data_generator.DataGenerator()
data.generate(dataset='patchcam')
data.plot()

keras.backend.clear_session()

# TODO: Build your network here
x = layers.Input(shape=data.x_train.shape[1:])
flat1  = layers.Flatten()(x)
y = layers.Dense(data.K, activation='softmax')(flat1)

model = keras.models.Model(inputs=x, outputs=y)
model.summary()

opt = keras.optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy','AUC'])
log = model.fit(data.x_train, data.y_train_oh, batch_size=batch_size, epochs=epochs, 
                validation_data=(data.x_valid, data.y_valid_oh), validation_freq=1,
                verbose=True)

util.evaluate(model, data)
util.plot_training(log)

# TODO: When you have finished your model development, you should 
# run inference on the test set and export a CSV file that can be 
# uploaded to Kaggle
#util.pred_test(model, data, name='your_submission.csv')
# Out:
# Data specification:
# 	Dataset type:           patchcam
# 	Number of classes:      2
# 	Number of channels:     3
# 	Training data shape:    (100000, 32, 32, 3)
# 	Validation data shape:  (32768, 32, 32, 3)
# 	Test data shape:        (32768, 32, 32, 3)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 3072)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 2)              │         6,146 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,146 (24.01 KB)
#  Trainable params: 6,146 (24.01 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 511us/step - AUC: 0.6283 - accuracy: 0.5963 - loss: 0.6857 - val_AUC: 0.7036 - val_accuracy: 0.6424 - val_loss: 0.6265
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 456us/step - AUC: 0.6855 - accuracy: 0.6370 - loss: 0.6458 - val_AUC: 0.6850 - val_accuracy: 0.6302 - val_loss: 0.6408
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 437us/step - AUC: 0.7112 - accuracy: 0.6571 - loss: 0.6310 - val_AUC: 0.7501 - val_accuracy: 0.6835 - val_loss: 0.6006
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 436us/step - AUC: 0.7245 - accuracy: 0.6689 - loss: 0.6231 - val_AUC: 0.7475 - val_accuracy: 0.6924 - val_loss: 0.6065
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 436us/step - AUC: 0.7332 - accuracy: 0.6773 - loss: 0.6183 - val_AUC: 0.7589 - val_accuracy: 0.6998 - val_loss: 0.5957
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 436us/step - AUC: 0.7364 - accuracy: 0.6794 - loss: 0.6175 - val_AUC: 0.7589 - val_accuracy: 0.6971 - val_loss: 0.5952
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 439us/step - AUC: 0.7354 - accuracy: 0.6783 - loss: 0.6224 - val_AUC: 0.7343 - val_accuracy: 0.6807 - val_loss: 0.6259
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 435us/step - AUC: 0.7359 - accuracy: 0.6793 - loss: 0.6224 - val_AUC: 0.7487 - val_accuracy: 0.6830 - val_loss: 0.6172
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 436us/step - AUC: 0.7420 - accuracy: 0.6833 - loss: 0.6168 - val_AUC: 0.7701 - val_accuracy: 0.7011 - val_loss: 0.5894
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 438us/step - AUC: 0.7428 - accuracy: 0.6844 - loss: 0.6165 - val_AUC: 0.7626 - val_accuracy: 0.7040 - val_loss: 0.5987
# Model performance:
# 	Train loss:          0.5918
# 	Train accuracy:      71.12
# 	Train AUC:           0.77
# 	Validation loss:     0.5987
# 	Validation accuracy: 70.40
# 	Validation AUC:     0.76
